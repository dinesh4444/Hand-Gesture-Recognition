# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout, Dense, Flatten

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape=(256,256,1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=150, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(units=6, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 254, 254, 32)      320
#
#  max_pooling2d_4 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 125, 125, 64)      18496
#
#  conv2d_7 (Conv2D)           (None, 123, 123, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 61, 61, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 59, 59, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 29, 29, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 27, 27, 256)       295168
#
#  max_pooling2d_7 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 43264)             0
#
#  dense_2 (Dense)             (None, 150)               6489750
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_3 (Dense)             (None, 6)                 906
#
# =================================================================
# Total params: 6,915,424
# Trainable params: 6,915,424
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=12,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  zoom_range=0.15,
                                  horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(directory=r'Directory Path\train',
                                                target_size=(256,256),
                                                color_mode='grayscale',
                                                 batch_size=8,
                                                classes=['FIVE','FOUR','NONE','ONE','THREE','TWO'],
                                                class_mode='categorical')
val_set = val_datagen.flow_from_directory(directory=r'Directory Path',
                                         target_size=(256,256),
                                         color_mode='grayscale',
                                         batch_size=8,
                                         classes= ['FIVE','FOUR','NONE','ONE','THREE','TWO'],
                                         class_mode= 'categorical')
# Out:
# Found 9081 images belonging to 6 classes.
# Found 3632 images belonging to 6 classes.

# %%
callback_list = [
    EarlyStopping(monitor='val_loss', patience=10),
    ModelCheckpoint(filepath='model.h5', monitor='val_loss', save_best_only=True, verbose=1)
]

# %%
history = model.fit_generator(training_set,
                             steps_per_epoch=37,
                             epochs=100,
                             validation_data=val_set,
                             validation_steps=7,
                             callbacks= callback_list)
# Out:
# C:\Users\HP.DESKTOP-5IHNLMQ\AppData\Local\Temp\ipykernel_12732\2954030446.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(training_set,
# Epoch 1/100
# 37/37 [==============================] - ETA: 0s - loss: 1.8252 - accuracy: 0.1689
# Epoch 1: val_loss improved from inf to 1.79733, saving model to model.h5
# 37/37 [==============================] - 88s 2s/step - loss: 1.8252 - accuracy: 0.1689 - val_loss: 1.7973 - val_accuracy: 0.1607
# Epoch 2/100
# 37/37 [==============================] - ETA: 0s - loss: 1.7945 - accuracy: 0.2027
# Epoch 2: val_loss improved from 1.79733 to 1.78521, saving model to model.h5
# 37/37 [==============================] - 99s 3s/step - loss: 1.7945 - accuracy: 0.2027 - val_loss: 1.7852 - val_accuracy: 0.1786
# Epoch 3/100
# 37/37 [==============================] - ETA: 0s - loss: 1.7931 - accuracy: 0.1554
# Epoch 3: val_loss did not improve from 1.78521
# 37/37 [==============================] - 84s 2s/step - loss: 1.7931 - accuracy: 0.1554 - val_loss: 1.7976 - val_accuracy: 0.1071
# Epoch 4/100
# 37/37 [==============================] - ETA: 0s - loss: 1.7910 - accuracy: 0.1824
# Epoch 4: val_loss did not improve from 1.78521
# 37/37 [==============================] - 79s 2s/step - loss: 1.7910 - accuracy: 0.1824 - val_loss: 1.7945 - val_accuracy: 0.1071
# Epoch 5/100
# 37/37 [==============================] - ETA: 0s - loss: 1.7923 - accuracy: 0.1554
# Epoch 5: val_loss did not improve from 1.78521
# 37/37 [==============================] - 77s 2s/step - loss: 1.7923 - accuracy: 0.1554 - val_loss: 1.7871 - val_accuracy: 0.2500
# Epoch 6/100
# 37/37 [==============================] - ETA: 0s - loss: 1.7938 - accuracy: 0.1486
# Epoch 6: val_loss improved from 1.78521 to 1.78362, saving model to model.h5
# 37/37 [==============================] - 78s 2s/step - loss: 1.7938 - accuracy: 0.1486 - val_loss: 1.7836 - val_accuracy: 0.1786
# Epoch 7/100
# 37/37 [==============================] - ETA: 0s - loss: 1.7708 - accuracy: 0.1926
# Epoch 7: val_loss improved from 1.78362 to 1.71211, saving model to model.h5
# 37/37 [==============================] - 73s 2s/step - loss: 1.7708 - accuracy: 0.1926 - val_loss: 1.7121 - val_accuracy: 0.1964
# Epoch 8/100
# 37/37 [==============================] - ETA: 0s - loss: 1.6542 - accuracy: 0.2973
# Epoch 8: val_loss improved from 1.71211 to 1.52166, saving model to model.h5
# 37/37 [==============================] - 73s 2s/step - loss: 1.6542 - accuracy: 0.2973 - val_loss: 1.5217 - val_accuracy: 0.2679
# Epoch 9/100
# 37/37 [==============================] - ETA: 0s - loss: 1.5140 - accuracy: 0.3581
# Epoch 9: val_loss improved from 1.52166 to 1.04793, saving model to model.h5
# 37/37 [==============================] - 72s 2s/step - loss: 1.5140 - accuracy: 0.3581 - val_loss: 1.0479 - val_accuracy: 0.6071
# Epoch 10/100
# 37/37 [==============================] - ETA: 0s - loss: 1.4343 - accuracy: 0.3446
# Epoch 10: val_loss did not improve from 1.04793
# 37/37 [==============================] - 72s 2s/step - loss: 1.4343 - accuracy: 0.3446 - val_loss: 1.5808 - val_accuracy: 0.3393
# Epoch 11/100
# 37/37 [==============================] - ETA: 0s - loss: 1.3265 - accuracy: 0.4257
# Epoch 11: val_loss improved from 1.04793 to 0.92014, saving model to model.h5
# 37/37 [==============================] - 74s 2s/step - loss: 1.3265 - accuracy: 0.4257 - val_loss: 0.9201 - val_accuracy: 0.6429
# Epoch 12/100
# 37/37 [==============================] - ETA: 0s - loss: 1.3460 - accuracy: 0.3919
# Epoch 12: val_loss did not improve from 0.92014
# 37/37 [==============================] - 73s 2s/step - loss: 1.3460 - accuracy: 0.3919 - val_loss: 1.1430 - val_accuracy: 0.4821
# Epoch 13/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0923 - accuracy: 0.5608
# Epoch 13: val_loss did not improve from 0.92014
# 37/37 [==============================] - 72s 2s/step - loss: 1.0923 - accuracy: 0.5608 - val_loss: 1.5039 - val_accuracy: 0.3393
# Epoch 14/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.5101
# Epoch 14: val_loss improved from 0.92014 to 0.90982, saving model to model.h5
# 37/37 [==============================] - 73s 2s/step - loss: 1.0986 - accuracy: 0.5101 - val_loss: 0.9098 - val_accuracy: 0.5893
# Epoch 15/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0478 - accuracy: 0.5304
# Epoch 15: val_loss improved from 0.90982 to 0.70568, saving model to model.h5
# 37/37 [==============================] - 72s 2s/step - loss: 1.0478 - accuracy: 0.5304 - val_loss: 0.7057 - val_accuracy: 0.6964
# Epoch 16/100
# 37/37 [==============================] - ETA: 0s - loss: 0.8961 - accuracy: 0.5743
# Epoch 16: val_loss improved from 0.70568 to 0.70516, saving model to model.h5
# 37/37 [==============================] - 74s 2s/step - loss: 0.8961 - accuracy: 0.5743 - val_loss: 0.7052 - val_accuracy: 0.6607
# Epoch 17/100
# 37/37 [==============================] - ETA: 0s - loss: 0.8512 - accuracy: 0.6216
# Epoch 17: val_loss improved from 0.70516 to 0.62921, saving model to model.h5
# 37/37 [==============================] - 72s 2s/step - loss: 0.8512 - accuracy: 0.6216 - val_loss: 0.6292 - val_accuracy: 0.6607
# Epoch 18/100
# 37/37 [==============================] - ETA: 0s - loss: 0.8785 - accuracy: 0.6216
# Epoch 18: val_loss did not improve from 0.62921
# 37/37 [==============================] - 70s 2s/step - loss: 0.8785 - accuracy: 0.6216 - val_loss: 0.9518 - val_accuracy: 0.5893
# Epoch 19/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7624 - accuracy: 0.6689
# Epoch 19: val_loss improved from 0.62921 to 0.54160, saving model to model.h5
# 37/37 [==============================] - 72s 2s/step - loss: 0.7624 - accuracy: 0.6689 - val_loss: 0.5416 - val_accuracy: 0.7500
# Epoch 20/100
# 37/37 [==============================] - ETA: 0s - loss: 0.8951 - accuracy: 0.6284
# Epoch 20: val_loss improved from 0.54160 to 0.50671, saving model to model.h5
# 37/37 [==============================] - 71s 2s/step - loss: 0.8951 - accuracy: 0.6284 - val_loss: 0.5067 - val_accuracy: 0.7500
# Epoch 21/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7952 - accuracy: 0.6486
# Epoch 21: val_loss did not improve from 0.50671
# 37/37 [==============================] - 70s 2s/step - loss: 0.7952 - accuracy: 0.6486 - val_loss: 0.5533 - val_accuracy: 0.7143
# Epoch 22/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7563 - accuracy: 0.6622
# Epoch 22: val_loss improved from 0.50671 to 0.41853, saving model to model.h5
# 37/37 [==============================] - 71s 2s/step - loss: 0.7563 - accuracy: 0.6622 - val_loss: 0.4185 - val_accuracy: 0.8393
# Epoch 23/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.6959
# Epoch 23: val_loss improved from 0.41853 to 0.40509, saving model to model.h5
# 37/37 [==============================] - 71s 2s/step - loss: 0.6659 - accuracy: 0.6959 - val_loss: 0.4051 - val_accuracy: 0.8571
# Epoch 24/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.7432
# Epoch 24: val_loss improved from 0.40509 to 0.27145, saving model to model.h5
# 37/37 [==============================] - 71s 2s/step - loss: 0.6082 - accuracy: 0.7432 - val_loss: 0.2714 - val_accuracy: 0.9107
# Epoch 25/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7907 - accuracy: 0.6747
# Epoch 25: val_loss did not improve from 0.27145
# 37/37 [==============================] - 68s 2s/step - loss: 0.7907 - accuracy: 0.6747 - val_loss: 0.3472 - val_accuracy: 0.9107
# Epoch 26/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.7230
# Epoch 26: val_loss did not improve from 0.27145
# 37/37 [==============================] - 70s 2s/step - loss: 0.5984 - accuracy: 0.7230 - val_loss: 0.3117 - val_accuracy: 0.8929
# Epoch 27/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5655 - accuracy: 0.7635
# Epoch 27: val_loss did not improve from 0.27145
# 37/37 [==============================] - 70s 2s/step - loss: 0.5655 - accuracy: 0.7635 - val_loss: 0.9603 - val_accuracy: 0.5536
# Epoch 28/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5799 - accuracy: 0.7601
# Epoch 28: val_loss did not improve from 0.27145
# 37/37 [==============================] - 71s 2s/step - loss: 0.5799 - accuracy: 0.7601 - val_loss: 0.3817 - val_accuracy: 0.8929
# Epoch 29/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5982 - accuracy: 0.7500
# Epoch 29: val_loss improved from 0.27145 to 0.13523, saving model to model.h5
# 37/37 [==============================] - 72s 2s/step - loss: 0.5982 - accuracy: 0.7500 - val_loss: 0.1352 - val_accuracy: 0.9821
# Epoch 30/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.7336
# Epoch 30: val_loss did not improve from 0.13523
# 37/37 [==============================] - 71s 2s/step - loss: 0.5989 - accuracy: 0.7336 - val_loss: 0.4239 - val_accuracy: 0.8036
# Epoch 31/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5169 - accuracy: 0.7905
# Epoch 31: val_loss did not improve from 0.13523
# 37/37 [==============================] - 74s 2s/step - loss: 0.5169 - accuracy: 0.7905 - val_loss: 0.3002 - val_accuracy: 0.8393
# Epoch 32/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7568
# Epoch 32: val_loss did not improve from 0.13523
# 37/37 [==============================] - 73s 2s/step - loss: 0.5443 - accuracy: 0.7568 - val_loss: 0.2788 - val_accuracy: 0.8750
# Epoch 33/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4626 - accuracy: 0.8209
# Epoch 33: val_loss did not improve from 0.13523
# 37/37 [==============================] - 72s 2s/step - loss: 0.4626 - accuracy: 0.8209 - val_loss: 0.3670 - val_accuracy: 0.8929
# Epoch 34/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6116 - accuracy: 0.7669
# Epoch 34: val_loss did not improve from 0.13523
# 37/37 [==============================] - 73s 2s/step - loss: 0.6116 - accuracy: 0.7669 - val_loss: 0.2792 - val_accuracy: 0.9464
# Epoch 35/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.8074
# Epoch 35: val_loss did not improve from 0.13523
# 37/37 [==============================] - 78s 2s/step - loss: 0.5363 - accuracy: 0.8074 - val_loss: 0.2965 - val_accuracy: 0.9286
# Epoch 36/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4190 - accuracy: 0.8615
# Epoch 36: val_loss did not improve from 0.13523
# 37/37 [==============================] - 76s 2s/step - loss: 0.4190 - accuracy: 0.8615 - val_loss: 0.2049 - val_accuracy: 0.9107
# Epoch 37/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.8108
# Epoch 37: val_loss did not improve from 0.13523
# 37/37 [==============================] - 76s 2s/step - loss: 0.4749 - accuracy: 0.8108 - val_loss: 0.1473 - val_accuracy: 0.9821
# Epoch 38/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4434 - accuracy: 0.8378
# Epoch 38: val_loss did not improve from 0.13523
# 37/37 [==============================] - 75s 2s/step - loss: 0.4434 - accuracy: 0.8378 - val_loss: 0.1817 - val_accuracy: 0.9464
# Epoch 39/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8514
# Epoch 39: val_loss did not improve from 0.13523
# 37/37 [==============================] - 78s 2s/step - loss: 0.4059 - accuracy: 0.8514 - val_loss: 0.2788 - val_accuracy: 0.8571
